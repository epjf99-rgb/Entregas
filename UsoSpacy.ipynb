# %% [markdown]
# #Configurar spacy

# %%
import spacy

# %%
# !python -m spacy download es_core_news_sm

# %% [markdown]
# Cargar corpus de español basado en noticias

# %%
nlp=spacy.load('es_core_news_sm')

# %% [markdown]
# #Texto analizar

# %%
texto="""
Muchos años después, frente al pelotón de fusilamiento,
el coronel Aureliano Buendía había de recordar aquella tarde remota en que su padre lo llevó a conocer el hielo.
Macondo era entonces una aldea de veinte casas de barro y cañabrava construidas a la orilla de un río de aguas diáfanas que se precipitaban por
un lecho de piedras pulidas, blancas y enormes como huevos prehistóricos.
El mundo era tan reciente, que muchas cosas carecían de nombre, y para mencionarlas había que señalarlas con el dedo.
Todos los años, por el mes de marzo, una familia de gitanos desarrapados plantaba su carpa cerca de la aldea, y con un grande alboroto de pitos
y timbales daban a conocer los nuevos inventos.
Primero llevaron el imán. Un gitano corpulento, de barba montaraz y manos de gorrión, que se presentó con el nombre de Melquíades,
hizo una truculenta demostración pública de lo que él mismo llamaba la octava maravilla de los sabios alquimistas de Macedonia.
Fue de casa en casa arrastrando dos lingotes metálicos, y todo el mundo se espantó al ver que los calderos, las pailas, las tenazas y los anafes
se caían de su sitio, y las maderas crujían por la desesperación de los clavos y los tornillos tratando de desenclavarse, y aun
los objetos perdidos desde hacía mucho tiempo aparecían por donde más se les había buscado,
y se arrastraban en desbandada turbulenta detrás de los fierros mágicos de Melquíades.
«Las cosas tienen vida propia —pregonaba el gitano con áspero acento—, todo es cuestión de despertarles el ánima.»
José Arcadio Buendía, cuya desaforada imaginación iba siempre más lejos que el ingenio de la naturaleza, y aun más allá del milagro y la magia,
pensó que era posible servirse de aquella invención inútil para desentrañar el oro de la tierra.
Melquíades, que era un hombre honrado, le previno: «Para eso no sirve.»
Pero José Arcadio Buendía no creía en aquel tiempo en la honradez de los gitanos, así que cambió su mulo y una partida de chivos por
los dos lingotes imantados. Úrsula Iguarán, su mujer, que contaba con aquellos animales para ensanchar el desmedrado patrimonio doméstico,
no consiguió disuadirlo. «Muy pronto ha de sobrarnos oro para empedrar la casa», replicó su marido.
Durante varios meses se empeñó en demostrar el acierto de sus conjeturas.
"""
texto

# %%
doc = nlp(texto)

# %% [markdown]
# Obtener tokens del texto

# %%
for token in doc:
  print(token)

# %%
palabras = [token.text for token in doc]
palabras

# %%
len(palabras)
# Out:
# 437

# %% [markdown]
# Analizar oraciones

# %%
for oracion in doc.sents:
  print(oracion)
# Out:
# Muchos años después, frente al pelotón de fusilamiento,
# el coronel Aureliano Buendía había de recordar aquella tarde remota en que su padre lo llevó a conocer el hielo.
# Macondo era entonces una aldea de veinte casas de barro y cañabrava construidas a la orilla de un río de aguas diáfanas que se precipitaban por un lecho de piedras pulidas, blancas y enormes como huevos prehistóricos.
# El mundo era tan reciente, que muchas cosas carecían de nombre, y para mencionarlas había que señalarlas con el dedo.
# Todos los años, por el mes de marzo, una familia de gitanos desarrapados plantaba su carpa cerca de la aldea, y con un grande alboroto de pitos y timbales daban a conocer los nuevos inventos.
# Primero llevaron el imán.
# Un gitano corpulento, de barba montaraz y manos de gorrión, que se presentó con el nombre de Melquíades, hizo una truculenta demostración pública de lo que él mismo llamaba la octava maravilla de los sabios alquimistas de Macedonia.
# ...

# %%
oraciones = [oracion for oracion in doc.sents]
oraciones
# Out:
# [Muchos años después, frente al pelotón de fusilamiento,
#  el coronel Aureliano Buendía había de recordar aquella tarde remota en que su padre lo llevó a conocer el hielo.,
#  Macondo era entonces una aldea de veinte casas de barro y cañabrava construidas a la orilla de un río de aguas diáfanas que se precipitaban por un lecho de piedras pulidas, blancas y enormes como huevos prehistóricos.,
#  El mundo era tan reciente, que muchas cosas carecían de nombre, y para mencionarlas había que señalarlas con el dedo.,
#  Todos los años, por el mes de marzo, una familia de gitanos desarrapados plantaba su carpa cerca de la aldea, y con un grande alboroto de pitos y timbales daban a conocer los nuevos inventos.,
#  Primero llevaron el imán.,
#  Un gitano corpulento, de barba montaraz y manos de gorrión, que se presentó con el nombre de Melquíades, hizo una truculenta demostración pública de lo que él mismo llamaba la octava maravilla de los sabios alquimistas de Macedonia.,
# ...

# %%
oraciones[-1]
# Out:
# Durante varios meses se empeñó en demostrar el acierto de sus conjeturas.

# %%
type(oraciones[-1])
# Out:
# spacy.tokens.span.Span

# %% [markdown]
# Palabras

# %%
for token in oraciones[-1]:
  print(token)
# Out:
# Durante
# varios
# meses
# se
# empeñó
# en
# demostrar
# el
# acierto
# de
# sus
# conjeturas
# .

# %%
palabras = [ token for token in oraciones[-1]]
palabras
# Out:
# [Durante,
#  varios,
#  meses,
#  se,
#  empeñó,
#  en,
#  demostrar,
#  el,
#  acierto,
#  de,
#  sus,
#  conjeturas,
#  .,
#  ]

# %%
for p in palabras:
  print(p.text, p.pos_)  #POS significa Part of Speech
# Out:
# Durante ADP
# varios DET
# meses NOUN
# se PRON
# empeñó VERB
# en ADP
# demostrar VERB
# el DET
# acierto NOUN
# de ADP
# sus DET
# conjeturas NOUN
# . PUNCT
#
#  SPACE

# %% [markdown]
# Análisis dependencias

# %%
from spacy import displacy

displacy.render(oraciones[-1], style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="es" id="e19bcd5696a941a1a43d62be49563155-0" class="displacy" width="2325" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Durante</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">varios</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %% [markdown]
# Named Entities
#
#
# Named Entity Recognition - NER
#
# Reconocimiento Entidad Nombradas

# %%
for ent in doc.ents:
  print(ent.text, ent.label_)
# Out:
# Aureliano Buendía PER
# Macondo LOC
# El mundo era tan reciente MISC
# Todos los años MISC
# Primero PER
# Un gitano corpulento MISC
# Melquíades PER
# Macedonia LOC
# mágicos de Melquíades MISC
# áspero PER
# José Arcadio Buendía MISC
# Melquíades LOC
# Pero José Arcadio Buendía MISC
# Úrsula Iguarán PER

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Muchos años después, frente al pelotón de fusilamiento, <br>el coronel
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aureliano Buendía
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  había de recordar aquella tarde remota en que su padre lo llevó a conocer el hielo.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Macondo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# ...

# %% [markdown]
# Span

# %%
mi_span =doc[16:30]
mi_span
# Out:
# de recordar aquella tarde remota en que su padre lo llevó a conocer el

# %%
type(mi_span)
# Out:
# spacy.tokens.span.Span

# %%
mi_span =doc[-32:-1]
mi_span
# Out:
# . «Muy pronto ha de sobrarnos oro para empedrar la casa», replicó su marido. Durante varios meses se empeñó en demostrar el acierto de sus conjeturas.

# %% [markdown]
# Un token tiene propiedades y muchas de ellassirven para pre procesar el texto

# %%
for token in mi_span:
  print(token.text,token.i,token.is_alpha, token.is_stop,token.is_punct,token.is_lower)
# Out:
# . 405 False False True False
# « 406 False False True False
# Muy 407 True True False False
# pronto 408 True True False True
# ha 409 True True False True
# de 410 True True False True
# sobrarnos 411 True False False True
# oro 412 True False False True
# para 413 True True False True
# empedrar 414 True False False True
# la 415 True True False True
# casa 416 True False False True
# » 417 False False True False
# , 418 False False True False
# replicó 419 True False False True
# su 420 True True False True
# marido 421 True False False True
# . 422 False False True False
# Durante 423 True True False False
# varios 424 True True False True
# meses 425 True False False True
# se 426 True True False True
# empeñó 427 True False False True
# en 428 True True False True
# demostrar 429 True False False True
# el 430 True True False True
# acierto 431 True False False True
# de 432 True True False True
# sus 433 True True False True
# conjeturas 434 True False False True
# ...

# %% [markdown]
# Lemas

# %%
span_3= doc[0:40]
span_3
# Out:
# Muchos años después, frente al pelotón de fusilamiento,
# el coronel Aureliano Buendía había de recordar aquella tarde remota en que su padre lo llevó a conocer el hielo. Macondo era entonces una aldea de veinte casas

# %%
for token in span_3 :
  print(token.text, token.lemma_)
# Out:
# Muchos mucho
# años año
# después después
# , ,
# frente frente
# al al
# pelotón pelotón
# de de
# fusilamiento fusilamiento
# , ,
#
#
#
# el el
# coronel coronel
# Aureliano Aureliano
# Buendía Buendía
# había haber
# de de
# recordar recordar
# aquella aquel
# tarde tarde
# remota remoto
# en en
# que que
# su su
# padre padre
# lo él
# llevó llevar
# a a
# conocer conocer
# el el
# hielo hielo
# . .
# Macondo Macondo
# era ser
# entonces entonces
# una uno
# aldea aldea
# de de
# veinte veinte
# casas casa

# %% [markdown]
# Expresiones regulares

# %%
import re

texto = "Mi número de teléfono es 55-43-58-8070 y el otro es 55-29-726-622 y mi correo es javierperalta99@outlook.com y ej.pf@lasallistas.org.mx"

# Buscar la cadena de telefono
re.search(r'\d+', texto)
# Out:
# <re.Match object; span=(25, 27), match='55'>
